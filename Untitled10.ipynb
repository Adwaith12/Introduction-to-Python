# %% [markdown]
# <a href="https://colab.research.google.com/github/Adwaith12/Introduction-to-Python/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("enter a number to be multiplied")) 
for y in range(1,11):
    print(y*x)
# Out:
# enter a number to be multiplied12
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120

# %%
i=1
while(i<=5):
    j=1
    while(j<=i):
        print("*",end="")
        j=j+1
    print()    
    i=i+1
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
   j=1
   for j in range(1,i):
        print("*",end="")
   print()
# Out:
# *
# **
# ***
# ****

# %%
# Out:
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * 
# ...
